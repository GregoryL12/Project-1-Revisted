# %% [markdown]
# # Project 1 Revisited

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ![linreg%20coef.png](attachment:linreg%20coef.png)

# %% [markdown]
# ### The graph shows that Outlet Location Type Tier 2 has the largest impact on sale of items.

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ![dtfeat.png](attachment:dtfeat.png)

# %% [markdown]
# ### Item MRP has the most importance in a decision tree model.

# %% [markdown]
# # Global Explanation

# %% [markdown]
# ## Shap Bar

# %% [markdown]
# ![dec%20shap.png](attachment:dec%20shap.png)

# %% [markdown]
# ### Both graphs are similar in the top 5 except for shap including outlet establishment year in the 4th spot but both graphs have item mrp at the top.

# %% [markdown]
# ## Shap Dot

# %% [markdown]
# ![shap%20dot.png](attachment:shap%20dot.png)

# %% [markdown]
# ### The top 3 features are Item MRP, Outlet Type Grocery Store, and Outlet Identifier OUT027 with Item MRP having the most positive impact to Item Sales while Outlet Type Grocery Store is the opposite.
