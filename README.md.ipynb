# %% [markdown]
# # Project 1 Revisited

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ![linreg%20coef-3.png](attachment:linreg%20coef-3.png)

# %% [markdown]
# ### Of the 3 largest coefficients, the only positive one is outlet_type and the other 2 are both negative and they are item_visibility and outlet_identifier_out019.
#
# Outlet_Type:
# The type of outlet a store is has a big effect on the item sales. Every level of outlet type increases the sales by $896.19 with Grocery Store being the lowest and Supermarket Type 3.
#
# Item_Visibility:
# This feauture has a negative coefficient to our target due to if an item has a visibility of 0 then it will decrease sales by $423.39.
#
# Outlet_Identifier_OUT019:
# This feature is the identifier for a particular store and it has the worst coefficient with item sales with a -$467.65.

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ![dtfeat-2.png](attachment:dtfeat-2.png)

# %% [markdown]
# ### These are the top 5 most important features for our target.
#
# Item_MRP:
# This is the strongest feature of them all with a feature importance of .45 which means the model has relied on this features 45% to make its decisions on how to split nodes which makes sense given the higher retail price.
#
# Outlet_Type:
# This feature is the 2nd strongest with a .19 feature importance meaning it is used almost 20% of the time. There are 4 types of stores in this data and each one has different impacts on the target.This feature was also important in the lin reg coefficient.
#
# Item_Visibility:
# This feature is the 3rd strongest with a score of .09 which means it was used in almost 10% of the time. Because every item has different amounts of visibility it is a hard feature to predict but the highest saling items tend to also have high
# visibility.
#
# The final 2 are Item_Establishment Year 1985 and Item Weight with scores of .06 and .05 respectively. These features dont have much importance compared to the top 3 and are used only 6% and 5% respectively. One can assume outlets established in 1985 have more customers due to being a constant and in effect have decent item sales because of it. Item weight doesn't have much effect.

# %% [markdown]
# # Global Explanation

# %% [markdown]
# ## Shap Bar

# %% [markdown]
# ![dec%20shap-2.png](attachment:dec%20shap-2.png)

# %% [markdown]
# ### Both graphs are similar in the top 5 except for the graphs switching Outlet establishment year 1985 with Item Visibility

# %% [markdown]
# ## Shap Dot

# %% [markdown]
# ![shap%20dot-2.png](attachment:shap%20dot-2.png)

# %% [markdown]
# ### The top 3 features are Item MRP, Outlet Type, and Outlet establishment year 1985 with Item MRP having the most positive impact to Item Sales while Outlet Type is the opposite.

# %% [markdown]
# ## Lime tabular explanation

# %% [markdown]
# ![lime%20max.PNG](attachment:lime%20max.PNG)

# %% [markdown]
# ### This is the maximum sales version of the graph.

# %% [markdown]
# This example row is the max item_sales row and these are the features that led to that value.
#
# These are the top positives:
#
# Item_MRP: 235
# This feature is the largest positive value and has led to an increase in sales by 1658.9 rupees.
#
# Outlet Establishment Year 1985: 1
# This feature is the 2nd highest positive and we can assume the outlet is reputable and sales good items with sales of 983.34
#
# Outlet Type: 3
# This feature is the 3rd highest positive feauture with an increase in sales of 628 rupees. This type of store seems to be a profitable one.
#
# These are the top negatives:
#
# Item Type Breakfast and Item Type Meats are the 2 highest negatives with breakfast being a negative 348 and 234 respectively. One can assume this shop or these customers are not high on breakfast and meat and don't consume a lot of either one.

# %% [markdown]
# ![lime%20min.PNG](attachment:lime%20min.PNG)

# %% [markdown]
# ### This is the minimum sales version of the graph.

# %% [markdown]
# This example row is the min item_sales row and these are the features that led to that value.
#
# These are the top negatives:
#
# Item_MRP: 32.89
# This feature is the largest negative value and has led to an decrease in sales by 626.67 rupees.
#
# Outlet Establishment Year 1985: 0
# This feature is the 2nd highest negative and must not be a popular store because it has a negative 959.39.
#
# Outlet Type: 0
# This feature is the 3rd highest negative feauture and is the least popular type of the store and has led to a decrease of 483.43 rupees.

# %% [markdown]
# ##  Individual Force Plot

# %% [markdown]
# ![shap%20force%20max.PNG](attachment:shap%20force%20max.PNG)

# %% [markdown]
# ### This is the maximum sales version of the graph.

# %% [markdown]
# - Base value is 2,210
# - The shap value is 13,086.96
# - The red features show that this is a great push towards higher sales
# - Item MRP is the most important feature with a value of 235 rupees.
# - Outlet Type=3, Outlet Establishment Year 1985=1, and Item Visibilty= 0.01055 are also important values that lead to higher revenue.

# %% [markdown]
# ![shap%20force%20min.PNG](attachment:shap%20force%20min.PNG)

# %% [markdown]
# ### This is the minimum sales version of the graph.

# %% [markdown]
# - Base value is 2,210
# - The shap value is 33.29
# - The blue features show that this is a great push towards lower sales
# - Item MRP is still the most important feature but this time with a value of 32.89 rupees.
# - The only other feature listed is Outlet Type= 0 which is shown to be the least profitable outlet type there is in this data.
